# %% [markdown]
# ##### This netflix Data set has information about the TV Shows and Movies available on Netflix till 2021.

# %% [markdown]
# ##### This datase is collected from kaggle website  for free.

# %%
# importing the dataset
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the Dataset

# %%
df=pd.read_csv("8. Netflix Dataset.csv")

# %% [markdown]
# ##### Getting some basic information about the dataset

# %% [markdown]
# ### 1. Head()

# %%
# To show top 5 records of the dataset
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# To show the No. of Rows and Columns
df.shape
# Out:
# (7789, 11)

# %%
# To show No total values(elements) in the dataset.
df.size
# Out:
# 85679

# %%
# To show the column Name
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
# To show the the data type of the column
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# To show index,columns,data-type of each memory at once
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# #### Task.1.Check the Duplicate Record in dataset, and remove the duplicate records.

# %% [markdown]
# ### Duplicate()

# %%
df.head(50)
# Out:
#    Show_Id Category                                Title  \
# 0       s1  TV Show                                   3%
# 1       s2    Movie                                07:19
# 2       s3    Movie                                23:59
# 3       s4    Movie                                    9
# 4       s5    Movie                                   21
# 5       s6  TV Show                                   46
# 6       s7    Movie                                  122
# 7       s8    Movie                                  187
# 8       s9    Movie                                  706
# 9      s10    Movie                                 1920
# 10     s11    Movie                                 1922
# 11     s12  TV Show                                 1983
# 12     s13  TV Show                                 1994
# 13     s14    Movie                                2,215
# 14     s15    Movie                                 3022
# ...

# %%
# Check duplicate Records
df.duplicated().sum()
# Out:
# 2

# %%
# Check duplicate Records row wise
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# To Remove duplicate Rows Permanently
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# ##### Task.2. check Null value present in the dataset

# %% [markdown]
# #### isnull()

# %%
# To show the count of null value in each columns
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# #### Show null value using Heatmap

# %%
# using heat map to show null value count
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# It drop the row that contain missing value
df.dropna(inplace= True)

# %%
df.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %% [markdown]
# ### Q.1. In which year highest number of the TV shows & Movies were relised.

# %%
df["df_New"] = pd.to_datetime(df['Release_Date'])

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# df_New          datetime64[ns]
# dtype: object

# %% [markdown]
# #### df.year.value_counts()

# %%
# It count the occurance of all indivisual year in data column.
df["df_New"].dt.year.value_counts()
# Out:
# 2019    1337
# 2020    1229
# 2018    1115
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: df_New, dtype: int64

# %% [markdown]
# ###### Bar Graph

# %%
df["df_New"].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Q.3. How many Movies & TV shows are in the datset

# %%
# To group all Unique item of a column and show their count
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      4673
# TV Show     136
# Name: Category, dtype: int64

# %%
# To show the count of allvunique value of any column in the form of bar graph.
sns.countplot(df['Category'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ### Q.3. Show all the movies that wear release in year 2000.

# %%
# To create new year column it concider only year.
df['Year'] = df['df_New'].dt.year

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     df_New  Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %% [markdown]
# ###### Filtering

# %%
df[(df['Category'] == 'Movie') & (df['Year'] == 2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, df_New, Year]
# Index: []

# %% [markdown]
# ### Q.4. Show Tv show Were released in india only.

# %%
df[(df['Category']== 'TV Show') & (df['Country']== 'India')]
# Out:
#      Show_Id Category                                  Title  \
# 132     s133  TV Show                              7 (Seven)
# 2406   s2407  TV Show                                  GHOUL
# 3119   s3120  TV Show           Jamtara - Sabka Number Ayega
# 4724   s4725  TV Show                        Paava Kadhaigal
# 6037   s6037  TV Show  Th Eena Meena Deeka Chase Comedy Show
#
#                                                Director  \
# 132                                         Nizar Shafi
# 2406                                     Patrick Graham
# 3119                                    Soumendra Padhi
# 4724  Sudha Kongara, Vignesh Shivan, Gautham Vasudev...
# 6037                                      Dheeraj Berry
#
#                                                    Cast Country  \
# 132   Rahman, Havish, Regina Cassandra, Nandita Swet...   India
# 2406  Radhika Apte, Manav Kaul, Ratnabali Bhattachar...   India
# ...

# %% [markdown]
# #### Q.5. Show Top 10 Directors, who gave the highest no of TV Show and Movies to Netflix?

# %%
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %%
###### Show all ther records, where "comedies" or "country is United Kingdom"

# %%
df[(df['Category']== 'Movie') & (df['Type']== 'Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
df[(df['Category']== 'Movie') & (df['Type']== 'Comedies') | (df['Country']== 'United Kingdom')]
# Out:
#      Show_Id Category                       Title  \
# 33       s34    Movie                #realityhigh
# 72       s73    Movie                    17 Again
# 82       s83    Movie         2036 Origin Unknown
# 84       s85    Movie                   21 & Over
# 93       s94    Movie           27: Gone Too Soon
# ...      ...      ...                         ...
# 7615   s7614    Movie  Why Are We Getting So Fat?
# 7623   s7622    Movie                   Wild Oats
# 7634   s7633    Movie                Wine Country
# 7664   s7663    Movie                     Work It
# 7725   s7724    Movie                You Can Tutu
#
#                                     Director  \
# 33                          Fernando Lebrija
# 72                               Burr Steers
# 82                             Hasraf Dulull
# 84                    Jon Lucas, Scott Moore
# 93                         Simon Napier-Bell
# ...                                      ...
# ...

# %% [markdown]
# ## Q.6. In how many movies/Shows, Tom cruise was cast?

# %%
df[df['Cast']== 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, df_New, Year]
# Index: []

# %%
# There is not  a single categeory of tv shows or where only the cast isTom cruise.There is a tom cruised only cast column no othe name shoud be present with this single name so iot is showing 0 result

# %%
df[df['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     df_New  Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %%
# We tried to filtering to find for a perticular element from the data set but the ans was zero bcz this filtering doesn't appling wher is the multiple element on a column then we use the (str.contains()) function to find this element from the data set and we found the result.

# %% [markdown]
# ### Q.7. What are the different Ratings defined by Netflix?

# %% [markdown]
# ##### nunique()

# %%
df['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# #### unique()

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### Q.8.How many movies got the 'TV-14' in India?

# %%
df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14')].shape
# Out:
# (1098, 13)

# %%
df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14') & (df['Country'] == 'India')].shape
# Out:
# (486, 13)

# %% [markdown]
# #### Q.9. How many Tv show got the R Rating ?

# %%
df[(df['Category'] == 'TV Show') & (df['Rating'] == 'R')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, df_New, Year]
# Index: []

# %% [markdown]
# ##### Q.10. What is the maximum duration of a movieshow on Netflix ?

# %%
df.Duration.unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %%
df.Duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# first step is we have to split data into two different columns
# first column will take out the numeric and the second column is take out the str value.
# to create two different columns for a single column we are use str.split() function.

# %%
df[['Minutes', 'Unit']] = df['Duration'].str.split(' ', expand = True)

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
## Now we can easyly found the Maximum value.
df['Minutes'].max()
# Out:
# '99'

# %%
df['Minutes'].min()
# Out:
# '1'

# %%
df['Minutes'].mean()
# Out:
# inf

# %% [markdown]
# #### Q.11. Which indivisual country has the highest No of TV show ?

# %%
# create a new data 
df_tvshow = df[df['Category'] == 'TV Show']

# %%
df_tvshow.head(2)
# Out:
#     Show_Id Category      Title     Director  \
# 5        s6  TV Show         46  Serdar Akar
# 132    s133  TV Show  7 (Seven)  Nizar Shafi
#
#                                                   Cast Country   Release_Date  \
# 5    Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey   July 1, 2017
# 132  Rahman, Havish, Regina Cassandra, Nandita Swet...   India  July 30, 2019
#
#     Rating  Duration                                             Type  \
# 5    TV-MA  1 Season  International TV Shows, TV Dramas, TV Mysteries
# 132  TV-14  1 Season                                         TV Shows
#
#                                            Description     df_New  Year  \
# 5    A genetics professor experiments with a treatm... 2017-07-01  2017
# 132  Multiple women report their husbands as missin... 2019-07-30  2019
#
#     Minutes    Unit
# 5         1  Season
# 132       1  Season

# %%
df_tvshow.Country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Canada                                                            3
# Thailand                                                          3
# Nigeria                                                           3
# France                                                            3
# China                                                             2
# ...

# %%
df_tvshow.Country.value_counts().head(1)
# Out:
# United States    27
# Name: Country, dtype: int64

# %% [markdown]
# #### Q.12. How can we sort the dataset by year?

# %%
df.sort_values(by='Year', ascending= False)
# Out:
#      Show_Id Category                        Title  \
# 2269   s2270    Movie                   Fred Claus
# 2349   s2350    Movie                    Gangaajal
# 6248   s6248    Movie           The Creative Brain
# 1673   s1674    Movie                  Death of Me
# 7147   s7146    Movie  Tony Parker: The Final Shot
# ...      ...      ...                          ...
# 2041   s2042    Movie                Even the Rain
# 3840   s3841    Movie  Mad Ron's Prevues from Hell
# 3248   s3249    Movie      Just Another Love Story
# 5766   s5766    Movie                     Splatter
# 7115   s7114    Movie         To and From New York
#
#                              Director  \
# 2269                     David Dobkin
# 2349                      Prakash Jha
# 6248  Jennifer Beamish, Toby Trackman
# 1673              Darren Lynn Bousman
# 7147                    Florent Bodin
# ...                               ...
# 2041                    Icíar Bollaín
# ...

# %% [markdown]
# #### Q.13. Find all the instances where:

# %% [markdown]
# #### category is 'Movie' and type is 'Dramas'

# %% [markdown]
# ##### or

# %% [markdown]
# #####  category is 'TV show' and type is 'kids TV'

# %%
df[(df['Category']== 'Movie') & (df['Type']== 'Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
df[(df['Category']== 'TV Show') & (df['Type']== "Kids' TV")]
# Out:
#      Show_Id Category                                       Title  \
# 276     s277  TV Show                                Abby Hatcher
# 3582   s3583  TV Show            Lego Friends: Girls on a Mission
# 6204   s6204  TV Show  The Cat in the Hat Knows a Lot About That!
# 7668   s7667  TV Show                               World of Winx
#
#                         Director  \
# 276                  Kyran Kelly
# 3582  Andrew Tan, Stephen Murray
# 6204            Tony Collingwood
# 7668              Iginio Straffi
#
#                                                    Cast  \
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# 3582  Jasmine St. Clair, Allegra Clark, Rosamund Mar...
# 6204  Martin Short, Alexa Torrington, Jacob Ewaniuk,...
# 7668  Haven Paschall, Alysha Deslorieux, Jessica Paq...
#
#                                     Country      Release_Date Rating  \
# 276                   United States, Canada      July 1, 2020   TV-Y
# ...

# %%
df[(df['Category']== 'Movie') & (df['Type']== 'Dramas') | (df['Category']== 'TV Show') & (df['Type']== "Kids' TV")]
# Out:
#      Show_Id Category                       Title          Director  \
# 4         s5    Movie                          21    Robert Luketic
# 7         s8    Movie                         187    Kevin Reynolds
# 170     s171    Movie                A Family Man     Mark Williams
# 232     s233    Movie  A Stoning in Fulham County     Larry Elikann
# 276     s277  TV Show                Abby Hatcher       Kyran Kelly
# ...      ...      ...                         ...               ...
# 7422   s7421    Movie                     Villain  Philip Barantini
# 7449   s7448    Movie                         VS.          Ed Lilly
# 7465   s7464    Movie                   Wakefield     Robin Swicord
# 7480   s7479    Movie                   War Horse  Steven Spielberg
# 7668   s7667  TV Show               World of Winx    Iginio Straffi
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
